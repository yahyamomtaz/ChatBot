# %%
import openai
import requests
import os
from langchain.llms import OpenAI

# %%
openai.api_key =('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')

# %%
openai_api_key = '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'

# %%
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt="...",
    openai_api_key="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"
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 response = openai.Completion.create(
#       2     engine="text-davinci-003",
#       3     prompt="...",
#       4     openai_api_key="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"
#       5 )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
# ...

# %%
llm = OpenAI(model_name="text-davinci-003", openai_api_key="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")
llm("explain large language models in one sentence")
# Out:
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: You exceeded your current quota, please check your plan and billing details..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: You exceeded your current quota, please check your plan and billing details..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: You exceeded your current quota, please check your plan and billing details..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 8.0 seconds as it raised RateLimitError: You exceeded your current quota, please check your plan and billing details..
# ...

# %%
export OPENAI_API_KEY=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
